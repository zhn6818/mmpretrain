# %%
from mmpretrain import ImageClassificationInferencer

# %%
inferencer = ImageClassificationInferencer('../resnet18_finetune.py' ,'../works/epoch_50.pth')
# Out:
# Loads checkpoint by local backend from path: ../works/epoch_50.pth
# ...

# %%
inferencer('../../data/classify/val/20/0000_0000 3_region_1 copy.jpg', show=True)
# Out:
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# [{'pred_scores': array([1.0000000e+00, 2.3804934e-11, 1.5496573e-08], dtype=float32),
#   'pred_label': 0,
#   'pred_score': 1.0,
#   'pred_class': '20'}]
